# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-db6b0127-b2f5-4567-9848-a0f376777b72" name="files[]" multiple disabled />
#      <output id="result-db6b0127-b2f5-4567-9848-a0f376777b72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hwk08.csv to hwk08.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import pandas as pd


data = pd.read_csv("hwk08.csv")

f1 = data['A'].values
f2 = data['B'].values

X = np.array(list(zip(f1, f2)))

# Number of clusters
#kmeans = KMeans(n_clusters=3)
# Fitting the input data
#kmeans = kmeans.fit(X)
# Getting the cluster labels
#labels = kmeans.predict(X)
# Centroid values
#centroids = kmeans.cluster_centers_

plt.rcParams['figure.figsize'] = (16, 9)

# Creating a sample dataset with 3 clusters
X, y = make_blobs(n_samples=800, n_features=3, centers=3)

# Initializing KMeans
kmeans = KMeans(n_clusters=3)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)
